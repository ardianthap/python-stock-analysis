# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

ticker = {'BCA' : 'BBCA.JK', 'IHSG' : '^JKSE', 'BTN' : 'BBTN.JK', 'MANDIRI' : 'BMRI.JK', 'BNI' : 'BBNI.JK', 'BRI': 'BBRI.JK'}
data = pd.DataFrame()

for t in ticker:
    data[t] = yf.download(ticker[t], start='2000-12-31', auto_adjust=False)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                    BCA        IHSG  BTN     MANDIRI         BNI        BRI
# Date
# 2004-06-08  102.763672  703.551636  NaN  130.148438  287.857452  66.198463
# 2004-06-09  104.211014  709.725403  NaN  135.807007  294.551880  69.454117
# 2004-06-10  104.211014  706.813538  NaN  135.807007  287.857452  69.454117
# 2004-06-11  104.211014  704.097534  NaN  135.807007  287.857452  70.539330
# 2004-06-14  102.763672  696.310974  NaN  134.610504  287.857452  70.539330

# %%
data.tail()
# Out:
#                BCA         IHSG    BTN  MANDIRI     BNI     BRI
# Date
# 2025-02-26  8775.0  6606.178223  900.0   4920.0  4350.0  3820.0
# 2025-02-27  8525.0  6485.448242  895.0   4660.0  4340.0  3630.0
# 2025-02-28  8425.0  6270.597168  835.0   4600.0  4030.0  3360.0
# 2025-03-03  8800.0  6519.658203  880.0   4900.0  4260.0  3670.0
# 2025-03-04  8850.0  6380.400879  855.0   4840.0  4220.0  3670.0

# %%
# Normalized comparation BBCA against IHSG
normalized_data = (data / data.iloc[0]) * 100
print(normalized_data)
normalized_data.plot(figsize = (15, 8))
plt.show()
# Out:
#                     BCA        IHSG  BTN      MANDIRI          BNI  \
# Date
# 2004-06-08   100.000000  100.000000  NaN   100.000000   100.000000
# 2004-06-09   101.408418  100.877514  NaN   104.347781   102.325605
# 2004-06-10   101.408418  100.463634  NaN   104.347781   100.000000
# 2004-06-11   101.408418  100.077592  NaN   104.347781   100.000000
# 2004-06-14   100.000000   98.970841  NaN   103.428444   100.000000
# ...                 ...         ...  ...          ...          ...
# 2025-02-26  8539.009788  938.975604  NaN  3780.298938  1511.164628
# 2025-02-27  8295.733156  921.815530  NaN  3580.527042  1507.690686
# 2025-02-28  8198.422503  891.277463  NaN  3534.425836  1399.998495
# 2025-03-03  8563.337451  926.677997  NaN  3764.931869  1479.899153
# 2025-03-04  8611.992778  906.884521  NaN  3718.830662  1466.003386
#
#                     BRI
# Date
# 2004-06-08   100.000000
# 2004-06-09   104.918020
# 2004-06-10   104.918020
# 2004-06-11   106.557352
# 2004-06-14   106.557352
# ...                 ...
# 2025-02-26  5770.526688
# 2025-02-27  5483.510963
# 2025-02-28  5075.646511
# 2025-03-03  5543.935326
# 2025-03-04  5543.935326
#
# [5127 rows x 6 columns]

# %%
log_returns = np.log(1+ data.pct_change())
log_returns.tail()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7440\3905831094.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   log_returns = np.log(1+ data.pct_change())
#                  BCA      IHSG       BTN   MANDIRI       BNI       BRI
# Date
# 2025-02-26 -0.005682  0.002894 -0.011050  0.010215  0.027974  0.005249
# 2025-02-27 -0.028904 -0.018444 -0.005571 -0.054293 -0.002301 -0.051018
# 2025-02-28 -0.011800 -0.033689 -0.069392 -0.012959 -0.074108 -0.077292
# 2025-03-03  0.043548  0.038950  0.052490  0.063179  0.055503  0.088251
# 2025-03-04  0.005666 -0.021591 -0.028820 -0.012320 -0.009434  0.000000

# %%
# Plotting the stock price to see the distribution of mean
log_returns['BCA'].plot(figsize = (10, 6))
plt.show()

# %% [markdown]
# #### Comparing BBCA performance to HIMBARA Banks
